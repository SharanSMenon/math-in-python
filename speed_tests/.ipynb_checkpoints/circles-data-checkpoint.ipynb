# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use("ggplot")

# %%
from sklearn.datasets import make_moons, make_circles

# %%
X, Y = make_circles(noise=0.15, factor=0.3, random_state=1, n_samples=500)

# %%
plt.scatter(X[:,0], X[:,1], c=Y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.36, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# %%
from tqdm import tqdm

# %%
N_RUNS=1000

# %%
accs = np.zeros((N_RUNS))

# %%
for i in tqdm(range(N_RUNS)):
#     model = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)
#     model = MLPClassifier(alpha=1, max_iter=50)
    model = 
    model.fit(X_train, y_train)
    accs[i] = model.score(X_test, y_test)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]/Users/sharansajivmenon/miniforge3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/sharansajivmenon/miniforge3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/sharansajivmenon/miniforge3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
accs.mean()
# Out:
# 0.9334611111111111

# %% [markdown]
# ## Model Scores
#
# ### M1
#
# - Random Forest: 181 it/s, 0.95
# - Neural Network (1000): 4.3 it/s, 0.98
# - Neural Network (100): 27.43 it/s, 0.93
